# %%
import numpy as np
import os

# Load images
first_folder_path = '/mnt/storage2/PanNuke/fold1'
images_path = os.path.join(first_folder_path, 'images.npy')
images = np.load(images_path)
print(images.shape)  # Check the shape of the images array
# Out:
# (2656, 256, 256, 3)

# %%
import cv2
import numpy as np
from sklearn.decomposition import PCA

# %%
from __future__ import annotations

# Clear logger to use tiatoolbox.logger
import logging

if logging.getLogger().hasHandlers():
    logging.getLogger().handlers.clear()

from pathlib import Path

import matplotlib as mpl
import matplotlib.pyplot as plt
import requests
import skimage.color

from tiatoolbox import data, logger
from tiatoolbox.tools import stainnorm
from tiatoolbox.wsicore import wsireader

# %%
import os  # Module for interacting with the operating system (paths, directories).
import requests  # Library to send HTTP requests for downloading images.
import numpy as np  # Library for numerical operations on arrays.
from PIL import Image  # Module for handling image files.
from io import BytesIO  # Used to handle byte streams in memory.
from tiatoolbox.tools.stainnorm import ReinhardNormalizer  # Stain normalization tool.
import cv2  # OpenCV library for image processing.
from skimage.metrics import structural_similarity as ssim  # Function to compute SSIM.
from scipy.stats import pearsonr  # Function to compute Pearson Correlation Coefficient (PCC).

def download_image(image_url):
    """Download an image from a given URL."""
    response = requests.get(image_url)  # Send GET request to download image.
    response.raise_for_status()  # Raise an error if the request failed.
    img = Image.open(BytesIO(response.content)).convert("RGB")  # Convert response content into an RGB image.
    return np.array(img)  # Return the image as a NumPy array.

def calculate_pcc(original_image, normalized_image):
    """Calculate Pearson Correlation Coefficient (PCC) for each color channel."""
    pcc_r = pearsonr(original_image[:, :, 0].flatten(), normalized_image[:, :, 0].flatten())[0]  # PCC for red channel.
    pcc_g = pearsonr(original_image[:, :, 1].flatten(), normalized_image[:, :, 1].flatten())[0]  # PCC for green channel.
    pcc_b = pearsonr(original_image[:, :, 2].flatten(), normalized_image[:, :, 2].flatten())[0]  # PCC for blue channel.
    return (pcc_r + pcc_g + pcc_b) / 3  # Return average PCC across RGB channels.

def calculate_amce_alpha(target_image, processed_image):
    """Calculate AMCE-alpha (Eα)."""
    mean_target_alpha = np.mean(target_image[:, :, 0])  # Mean of the red channel in the target image.
    mean_processed_alpha = np.mean(processed_image[:, :, 0])  # Mean of the red channel in the processed image.
    return abs(mean_target_alpha - mean_processed_alpha)  # Return absolute difference between red channel means.

def calculate_amce_beta(target_image, processed_image):
    """Calculate AMCE-beta (Eβ)."""
    mean_target_beta = np.mean(target_image[:, :, 2])  # Mean of the blue channel in the target image.
    mean_processed_beta = np.mean(processed_image[:, :, 2])  # Mean of the blue channel in the processed image.
    return abs(mean_target_beta - mean_processed_beta)  # Return absolute difference between blue channel means.

def calculate_rse(original_image, normalized_image):
    """Calculate Relative Square Error (RSE)."""
    diff = original_image.astype(np.float32) - normalized_image.astype(np.float32)  # Compute pixel differences.
    squared_error = np.sum(diff ** 2)  # Sum of squared differences.
    original_squared_sum = np.sum(original_image.astype(np.float32) ** 2)  # Sum of squared pixel values of original.
    return squared_error / original_squared_sum if original_squared_sum != 0 else 0  # Return RSE.

def calculate_psnr(original_image, normalized_image):
    """Calculate Peak Signal-to-Noise Ratio (PSNR)."""
    mse = np.mean((original_image.astype(np.float32) - normalized_image.astype(np.float32)) ** 2)  # Mean Squared Error.
    return 10 * np.log10((255.0 ** 2) / mse) if mse != 0 else float('inf')  # Return PSNR (in decibels).

def calculate_ssim(original_image, normalized_image):
    """Calculate Structural Similarity Index (SSIM)."""
    original_image_gray = cv2.cvtColor(original_image, cv2.COLOR_RGB2GRAY)  # Convert original to grayscale.
    normalized_image_gray = cv2.cvtColor(normalized_image, cv2.COLOR_RGB2GRAY)  # Convert normalized to grayscale.
    original_image_gray = original_image_gray.astype(np.float64) / 255.0  # Normalize pixel values (original).
    normalized_image_gray = normalized_image_gray.astype(np.float64) / 255.0  # Normalize pixel values (normalized).
    return ssim(original_image_gray, normalized_image_gray, data_range=1.0)  # Return SSIM score.

def normalize_stains(input_folder, output_folder, reference_image_url):
    """Normalize stains in images from the input folder using the reference image."""
    # Create output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)  # Create output folder if it doesn't exist.

    # Download the reference image and convert to array
    target_image = download_image(reference_image_url)  # Download and convert reference image to array.

    # Initialize the Reinhard Normalizer
    stain_normalizer = ReinhardNormalizer()  # Create a Reinhard Normalizer object.
    # Fit the normalizer with the target image
    stain_normalizer.fit(target_image)  # Fit the normalizer using the reference image.

    # Process each image in the input folder
    for filename in sorted(os.listdir(input_folder)):  # Loop through each file in the input folder.
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.tiff')):  # Check if the file is an image.
            source_path = os.path.join(input_folder, filename)  # Create the full source path for the image.
            source_image = Image.open(source_path).convert("RGB")  # Open and convert the image to RGB.
            sample = np.array(source_image)  # Convert image to a NumPy array.

            # Normalize the image using the Reinhard Normalizer
            normed_sample = stain_normalizer.transform(sample.copy())  # Perform stain normalization.

            # Save the normalized image
            output_image = Image.fromarray(normed_sample.astype('uint8'))  # Convert array back to an image.
            output_path = os.path.join(output_folder, filename)  # Define the output file path.
            output_image.save(output_path)  # Save the normalized image.

            # Calculate metrics for the image
            pcc_value = calculate_pcc(sample, normed_sample)  # Calculate PCC.
            amce_alpha_value = calculate_amce_alpha(target_image, normed_sample)  # Calculate AMCE-alpha.
            amce_beta_value = calculate_amce_beta(target_image, normed_sample)  # Calculate AMCE-beta.
            rse_value = calculate_rse(sample, normed_sample)  # Calculate RSE.
            psnr_value = calculate_psnr(sample, normed_sample)  # Calculate PSNR.
            ssim_value = calculate_ssim(sample, normed_sample)  # Calculate SSIM.

            # Print metrics for the current image
            print(f"Metrics for {filename}:")  # Print image filename.
            print(f"PCC: {pcc_value:.4f}")  # Print PCC value.
            print(f"AMCE-alpha (Eα): {amce_alpha_value:.4f}")  # Print AMCE-alpha value.
            print(f"AMCE-beta (Eβ): {amce_beta_value:.4f}")  # Print AMCE-beta value.
            print(f"RSE: {rse_value:.4f}")  # Print RSE value.
            print(f"PSNR: {psnr_value:.4f}")  # Print PSNR value.
            print(f"SSIM: {ssim_value:.4f}")  # Print SSIM value.
            

# Example usage
input_folder = "/mnt/storage2/PanNuke/fold1/Thyroid/images"  # Replace with your input folder path.
output_folder = "/mnt/storage2/PanNuke/folder1/Reinhard_folder/R_Testis"  # Replace with your output folder path.
reference_image_url = "https://data.kitware.com/api/v1/file/57718cc28d777f1ecd8a883c/download"  # Replace with your URL.

normalize_stains(input_folder, output_folder, reference_image_url)  # Call function to start normalization process.
# Out:
# Metrics for img_Testis_1_01411.png:
# PCC: 0.9994
# AMCE-alpha (Eα): 1.6229
# AMCE-beta (Eβ): 0.1182
# RSE: 0.0125
# PSNR: 22.4072
# SSIM: 0.9921
# --------------------------------------------------
# Metrics for img_Testis_1_01412.png:
# PCC: 0.9995
# AMCE-alpha (Eα): 1.7673
# AMCE-beta (Eβ): 0.3685
# RSE: 0.0061
# PSNR: 26.0405
# SSIM: 0.9970
# --------------------------------------------------
# Metrics for img_Testis_1_01413.png:
# PCC: 0.9995
# AMCE-alpha (Eα): 1.8912
# AMCE-beta (Eβ): 0.6919
# RSE: 0.0066
# PSNR: 25.6047
# SSIM: 0.9966
# --------------------------------------------------
# Metrics for img_Testis_1_01414.png:
# PCC: 0.9915
# AMCE-alpha (Eα): 2.8902
# AMCE-beta (Eβ): 0.5055
# RSE: 0.0091
# PSNR: 23.9288
# SSIM: 0.9565
# --------------------------------------------------
# Metrics for img_Testis_1_01415.png:
# PCC: 0.9986
# AMCE-alpha (Eα): 1.7772
# AMCE-beta (Eβ): 0.3679
# RSE: 0.0040
# PSNR: 27.8978
# SSIM: 0.9876
# --------------------------------------------------
# Metrics for img_Testis_1_01416.png:
# PCC: 0.9965
# AMCE-alpha (Eα): 1.7422
# AMCE-beta (Eβ): 0.3261
# RSE: 0.0179
# PSNR: 20.4815
# SSIM: 0.9723
# --------------------------------------------------
# Metrics for img_Testis_1_01417.png:
# PCC: 0.9985
# AMCE-alpha (Eα): 2.0173
# AMCE-beta (Eβ): 0.1663
# RSE: 0.0136
# PSNR: 21.9602
# SSIM: 0.9737
# --------------------------------------------------
# Metrics for img_Testis_1_01418.png:
# PCC: 0.9978
# AMCE-alpha (Eα): 1.8747
# AMCE-beta (Eβ): 0.2899
# RSE: 0.0069
# PSNR: 25.1156
# SSIM: 0.9912
# --------------------------------------------------
# Metrics for img_Testis_1_01419.png:
# PCC: 0.9953
# AMCE-alpha (Eα): 1.9220
# AMCE-beta (Eβ): 0.2446
# RSE: 0.0093
# PSNR: 23.9594
# SSIM: 0.9274
# --------------------------------------------------
# Metrics for img_Testis_1_01420.png:
# PCC: 0.9973
# AMCE-alpha (Eα): 1.8497
# AMCE-beta (Eβ): 0.3012
# RSE: 0.0205
# PSNR: 19.8553
# SSIM: 0.9663
# --------------------------------------------------
# Metrics for img_Testis_1_01421.png:
# PCC: 0.9944
# AMCE-alpha (Eα): 1.8899
# AMCE-beta (Eβ): 0.4210
# RSE: 0.0096
# PSNR: 23.5510
# SSIM: 0.9643
# --------------------------------------------------
# Metrics for img_Testis_1_01422.png:
# PCC: 0.9959
# AMCE-alpha (Eα): 1.5423
# AMCE-beta (Eβ): 0.5269
# RSE: 0.0099
# PSNR: 23.6771
# SSIM: 0.9375
# --------------------------------------------------
# Metrics for img_Testis_1_01423.png:
# PCC: 0.9968
# AMCE-alpha (Eα): 1.8238
# AMCE-beta (Eβ): 0.2840
# RSE: 0.0119
# PSNR: 22.5952
# SSIM: 0.9614
# --------------------------------------------------
# Metrics for img_Testis_1_01424.png:
# PCC: 0.9945
# AMCE-alpha (Eα): 2.0728
# AMCE-beta (Eβ): 0.5505
# RSE: 0.0125
# PSNR: 22.3833
# SSIM: 0.9532
# --------------------------------------------------
# Metrics for img_Testis_1_01425.png:
# PCC: 0.9963
# AMCE-alpha (Eα): 1.5300
# AMCE-beta (Eβ): 0.4530
# RSE: 0.0045
# PSNR: 27.3277
# SSIM: 0.9810
# --------------------------------------------------
# Metrics for img_Testis_1_01426.png:
# PCC: 0.9993
# AMCE-alpha (Eα): 1.4485
# AMCE-beta (Eβ): 0.1214
# RSE: 0.0502
# PSNR: 15.3438
# SSIM: 0.9260
# --------------------------------------------------
# Metrics for img_Testis_1_01427.png:
# PCC: 0.9994
# AMCE-alpha (Eα): 1.5408
# AMCE-beta (Eβ): 0.0572
# RSE: 0.0372
# PSNR: 17.7781
# SSIM: 0.9004
# --------------------------------------------------
# Metrics for img_Testis_1_01428.png:
# PCC: 0.9989
# AMCE-alpha (Eα): 1.4343
# AMCE-beta (Eβ): 0.3243
# RSE: 0.0241
# PSNR: 20.5029
# SSIM: 0.9288
# --------------------------------------------------
# Metrics for img_Testis_1_01429.png:
# PCC: 0.9959
# AMCE-alpha (Eα): 0.9270
# AMCE-beta (Eβ): 0.3118
# RSE: 0.0922
# PSNR: 11.5312
# SSIM: 0.9005
# --------------------------------------------------
# Metrics for img_Testis_1_01430.png:
# PCC: 0.9327
# AMCE-alpha (Eα): 0.5956
# AMCE-beta (Eβ): 2.1249
# RSE: 0.1185
# PSNR: 10.0289
# SSIM: 0.8695
# --------------------------------------------------
# Metrics for img_Testis_1_01431.png:
# PCC: 0.9981
# AMCE-alpha (Eα): 1.7194
# AMCE-beta (Eβ): 0.3913
# RSE: 0.0151
# PSNR: 21.4899
# SSIM: 0.9561
# --------------------------------------------------
# Metrics for img_Testis_1_01432.png:
# PCC: 0.9440
# AMCE-alpha (Eα): 0.2230
# AMCE-beta (Eβ): 1.5700
# RSE: 0.1263
# PSNR: 9.7752
# SSIM: 0.8016
# --------------------------------------------------
# Metrics for img_Testis_1_01433.png:
# PCC: 0.9146
# AMCE-alpha (Eα): 0.0089
# AMCE-beta (Eβ): 2.7931
# RSE: 0.1259
# PSNR: 9.7537
# SSIM: 0.8249
# --------------------------------------------------
# Metrics for img_Testis_1_01434.png:
# PCC: 0.9983
# AMCE-alpha (Eα): 1.7725
# AMCE-beta (Eβ): 0.2297
# RSE: 0.0646
# PSNR: 13.6975
# SSIM: 0.9354
# --------------------------------------------------
# Metrics for img_Testis_1_01435.png:
# PCC: 0.9965
# AMCE-alpha (Eα): 1.7127
# AMCE-beta (Eβ): 0.4570
# RSE: 0.0042
# PSNR: 27.3138
# SSIM: 0.9914
# --------------------------------------------------
# Metrics for img_Testis_1_01436.png:
# PCC: 0.9988
# AMCE-alpha (Eα): 1.6097
# AMCE-beta (Eβ): 0.5073
# RSE: 0.0159
# PSNR: 21.3412
# SSIM: 0.9425
# --------------------------------------------------
# Metrics for img_Testis_1_01437.png:
# PCC: 0.9994
# AMCE-alpha (Eα): 2.0087
# AMCE-beta (Eβ): 0.2947
# RSE: 0.0615
# PSNR: 14.0985
# SSIM: 0.9269
# --------------------------------------------------
# Metrics for img_Testis_1_01438.png:
# PCC: 0.9984
# AMCE-alpha (Eα): 1.4642
# AMCE-beta (Eβ): 0.3623
# RSE: 0.0249
# PSNR: 19.3392
# SSIM: 0.9198
# --------------------------------------------------
# Metrics for img_Testis_1_01439.png:
# PCC: 0.9986
# AMCE-alpha (Eα): 1.6384
# AMCE-beta (Eβ): 0.3230
# RSE: 0.0142
# PSNR: 22.1048
# SSIM: 0.9488
# --------------------------------------------------
# Metrics for img_Testis_1_01440.png:
# PCC: 0.9982
# AMCE-alpha (Eα): 1.6724
# AMCE-beta (Eβ): 0.2534
# RSE: 0.0175
# PSNR: 20.9765
# SSIM: 0.9368
# --------------------------------------------------
# Metrics for img_Testis_1_01441.png:
# PCC: 0.9996
# AMCE-alpha (Eα): 1.6377
# AMCE-beta (Eβ): 0.3532
# RSE: 0.0145
# PSNR: 22.2002
# SSIM: 0.9464
# --------------------------------------------------
# Metrics for img_Testis_1_01442.png:
# PCC: 0.9996
# AMCE-alpha (Eα): 1.5304
# AMCE-beta (Eβ): 0.2937
# RSE: 0.0284
# PSNR: 19.8682
# SSIM: 0.9181
# --------------------------------------------------
# Metrics for img_Testis_1_01443.png:
# PCC: 0.9961
# AMCE-alpha (Eα): 1.4896
# AMCE-beta (Eβ): 0.3895
# RSE: 0.0165
# PSNR: 20.7229
# SSIM: 0.9734
# --------------------------------------------------
# Metrics for img_Testis_1_01444.png:
# PCC: 0.9994
# AMCE-alpha (Eα): 1.6518
# AMCE-beta (Eβ): 0.3970
# RSE: 0.0121
# PSNR: 23.6793
# SSIM: 0.9780
# --------------------------------------------------
# Metrics for img_Testis_1_01445.png:
# PCC: 0.9984
# AMCE-alpha (Eα): 1.8022
# AMCE-beta (Eβ): 0.3516
# RSE: 0.0049
# PSNR: 27.3626
# SSIM: 0.9974
# --------------------------------------------------
# Metrics for img_Testis_1_02512.png:
# PCC: 0.9915
# AMCE-alpha (Eα): 3.0714
# AMCE-beta (Eβ): 0.8360
# RSE: 0.0561
# PSNR: 17.5886
# SSIM: 0.9389
# --------------------------------------------------
# Metrics for img_Testis_1_02513.png:
# PCC: 0.9894
# AMCE-alpha (Eα): 2.3645
# AMCE-beta (Eβ): 0.6429
# RSE: 0.0074
# PSNR: 24.6332
# SSIM: 0.9910
# --------------------------------------------------
# Metrics for img_Testis_1_02514.png:
# PCC: 0.9888
# AMCE-alpha (Eα): 2.5599
# AMCE-beta (Eβ): 0.9858
# RSE: 0.0054
# PSNR: 26.8149
# SSIM: 0.9891
# --------------------------------------------------
# Metrics for img_Testis_1_02515.png:
# PCC: 0.9917
# AMCE-alpha (Eα): 2.5446
# AMCE-beta (Eβ): 0.8903
# RSE: 0.0112
# PSNR: 23.8096
# SSIM: 0.9791
# --------------------------------------------------
# Metrics for img_Testis_1_02516.png:
# PCC: 0.9887
# AMCE-alpha (Eα): 2.0723
# AMCE-beta (Eβ): 0.6433
# RSE: 0.0095
# PSNR: 23.5841
# SSIM: 0.9834
# --------------------------------------------------
# Metrics for img_Testis_1_02517.png:
# PCC: 0.9957
# AMCE-alpha (Eα): 1.4926
# AMCE-beta (Eβ): 0.0917
# RSE: 0.0384
# PSNR: 17.0569
# SSIM: 0.9492
# --------------------------------------------------
# Metrics for img_Testis_1_02518.png:
# PCC: 0.9927
# AMCE-alpha (Eα): 1.6996
# AMCE-beta (Eβ): 0.3184
# RSE: 0.0634
# PSNR: 14.1236
# SSIM: 0.9117
# --------------------------------------------------
# Metrics for img_Testis_1_02519.png:
# PCC: 0.9973
# AMCE-alpha (Eα): 1.5500
# AMCE-beta (Eβ): 0.0367
# RSE: 0.0299
# PSNR: 18.4890
# SSIM: 0.9723
# --------------------------------------------------
# Metrics for img_Testis_1_02520.png:
# PCC: 0.9951
# AMCE-alpha (Eα): 1.6243
# AMCE-beta (Eβ): 0.1619
# RSE: 0.0536
# PSNR: 15.0739
# SSIM: 0.9297
# --------------------------------------------------
# Metrics for img_Testis_1_02521.png:
# PCC: 0.9985
# AMCE-alpha (Eα): 1.4043
# AMCE-beta (Eβ): 0.1967
# RSE: 0.0274
# PSNR: 18.3681
# SSIM: 0.9784
# --------------------------------------------------
# Metrics for img_Testis_1_02522.png:
# PCC: 0.9977
# AMCE-alpha (Eα): 1.8967
# AMCE-beta (Eβ): 0.1253
# RSE: 0.0206
# PSNR: 19.9383
# SSIM: 0.9847
# --------------------------------------------------
# Metrics for img_Testis_1_02523.png:
# PCC: 0.9975
# AMCE-alpha (Eα): 2.5492
# AMCE-beta (Eβ): 0.1812
# RSE: 0.0141
# PSNR: 21.8806
# SSIM: 0.9871
# --------------------------------------------------
# Metrics for img_Testis_1_02524.png:
# PCC: 0.9975
# AMCE-alpha (Eα): 1.7451
# AMCE-beta (Eβ): 0.1237
# RSE: 0.0199
# PSNR: 20.0745
# SSIM: 0.9864
# --------------------------------------------------
# Metrics for img_Testis_1_02525.png:
# PCC: 0.9969
# AMCE-alpha (Eα): 3.2312
# AMCE-beta (Eβ): 0.7626
# RSE: 0.0900
# PSNR: 16.2410
# SSIM: 0.9120
# --------------------------------------------------
# Metrics for img_Testis_1_02526.png:
# PCC: 0.9963
# AMCE-alpha (Eα): 2.7480
# AMCE-beta (Eβ): 0.1839
# RSE: 0.0910
# PSNR: 16.3170
# SSIM: 0.9242
# --------------------------------------------------
# Metrics for img_Testis_1_02527.png:
# PCC: 0.9987
# AMCE-alpha (Eα): 1.5669
# AMCE-beta (Eβ): 0.3518
# RSE: 0.0075
# PSNR: 25.5960
# SSIM: 0.9946
# --------------------------------------------------
# Metrics for img_Testis_1_02528.png:
# PCC: 0.9972
# AMCE-alpha (Eα): 2.9629
# AMCE-beta (Eβ): 0.3818
# RSE: 0.0866
# PSNR: 16.4969
# SSIM: 0.9296
# --------------------------------------------------
# Metrics for img_Testis_1_02529.png:
# PCC: 0.9989
# AMCE-alpha (Eα): 1.8027
# AMCE-beta (Eβ): 0.2931
# RSE: 0.0256
# PSNR: 20.8222
# SSIM: 0.9802
# --------------------------------------------------
# Metrics for img_Testis_1_02530.png:
# PCC: 0.9983
# AMCE-alpha (Eα): 2.1176
# AMCE-beta (Eβ): 0.2210
# RSE: 0.0360
# PSNR: 19.6069
# SSIM: 0.9729
# --------------------------------------------------
# Metrics for img_Testis_1_02531.png:
# PCC: 0.9950
# AMCE-alpha (Eα): 2.8861
# AMCE-beta (Eβ): 0.0316
# RSE: 0.0229
# PSNR: 21.1453
# SSIM: 0.9628
# --------------------------------------------------
# Metrics for img_Testis_1_02532.png:
# PCC: 0.9962
# AMCE-alpha (Eα): 2.8054
# AMCE-beta (Eβ): 0.2416
# RSE: 0.0236
# PSNR: 21.0943
# SSIM: 0.9756
# --------------------------------------------------
# Metrics for img_Testis_1_02533.png:
# PCC: 0.9964
# AMCE-alpha (Eα): 3.1913
# AMCE-beta (Eβ): 0.1253
# RSE: 0.0168
# PSNR: 22.3729
# SSIM: 0.9782
# --------------------------------------------------
# Metrics for img_Testis_1_02534.png:
# PCC: 0.9973
# AMCE-alpha (Eα): 2.2758
# AMCE-beta (Eβ): 0.1595
# RSE: 0.0191
# PSNR: 21.9509
# SSIM: 0.9695
# --------------------------------------------------
# Metrics for img_Testis_1_02535.png:
# PCC: 0.9983
# AMCE-alpha (Eα): 2.8759
# AMCE-beta (Eβ): 0.4499
# RSE: 0.0158
# PSNR: 22.5502
# SSIM: 0.9947
# --------------------------------------------------
# Metrics for img_Testis_1_02536.png:
# PCC: 0.9949
# AMCE-alpha (Eα): 3.0531
# AMCE-beta (Eβ): 0.0770
# RSE: 0.0213
# PSNR: 21.4705
# SSIM: 0.9520
# --------------------------------------------------

# %%
import os  # Provides functions to interact with the operating system, like creating directories.
import requests  # Allows making HTTP requests to download data from the internet.
import numpy as np  # Supports working with large, multi-dimensional arrays and matrices.
from PIL import Image  # Provides an Image class for opening, manipulating, and saving images.
from io import BytesIO  # Allows handling byte streams, useful for handling in-memory binary data.
from tiatoolbox.tools.stainnorm import MacenkoNormalizer  # Imports Macenko stain normalization from TIA Toolbox.
import cv2  # Provides image processing functions via OpenCV.
from skimage.metrics import structural_similarity as ssim  # Imports SSIM for image similarity comparison.
from scipy.stats import pearsonr  # Provides the Pearson correlation coefficient calculation.

# Function to download an image from a URL
def download_image(image_url):
    """Download an image from a given URL."""
    response = requests.get(image_url)  # Sends a GET request to the specified URL.
    response.raise_for_status()  # Raises an exception if the request was unsuccessful.
    img = Image.open(BytesIO(response.content)).convert("RGB")  # Opens the image in RGB mode.
    return np.array(img)  # Converts the image to a numpy array.

# Function to calculate the Pearson Correlation Coefficient for RGB channels
def calculate_pcc(original_image, normalized_image):
    """Calculate Pearson Correlation Coefficient (PCC) for each color channel."""
    # Flatten each RGB channel and calculate PCC between original and normalized images
    pcc_r = pearsonr(original_image[:, :, 0].flatten(), normalized_image[:, :, 0].flatten())[0]  # Red channel PCC
    pcc_g = pearsonr(original_image[:, :, 1].flatten(), normalized_image[:, :, 1].flatten())[0]  # Green channel PCC
    pcc_b = pearsonr(original_image[:, :, 2].flatten(), normalized_image[:, :, 2].flatten())[0]  # Blue channel PCC
    return (pcc_r + pcc_g + pcc_b) / 3  # Returns the average PCC across RGB channels.

# Function to calculate AMCE-alpha between target and processed images
def calculate_amce_alpha(target_image, processed_image):
    """Calculate AMCE-alpha (Eα)."""
    mean_target_alpha = np.mean(target_image[:, :, 0])  # Calculates the mean for the Red channel in the target image.
    mean_processed_alpha = np.mean(processed_image[:, :, 0])  # Calculates the mean for the Red channel in the processed image.
    return abs(mean_target_alpha - mean_processed_alpha)  # Returns the absolute difference.

# Function to calculate AMCE-beta between target and processed images
def calculate_amce_beta(target_image, processed_image):
    """Calculate AMCE-beta (Eβ)."""
    mean_target_beta = np.mean(target_image[:, :, 2])  # Calculates the mean for the Blue channel in the target image.
    mean_processed_beta = np.mean(processed_image[:, :, 2])  # Calculates the mean for the Blue channel in the processed image.
    return abs(mean_target_beta - mean_processed_beta)  # Returns the absolute difference.

# Function to calculate the Relative Square Error between two images
def calculate_rse(original_image, normalized_image):
    """Calculate Relative Square Error (RSE)."""
    diff = original_image.astype(np.float32) - normalized_image.astype(np.float32)  # Calculates pixel differences.
    squared_error = np.sum(diff ** 2)  # Sums the squared differences.
    original_squared_sum = np.sum(original_image.astype(np.float32) ** 2)  # Sums squares of original image values.
    return squared_error / original_squared_sum if original_squared_sum != 0 else 0  # Computes RSE if valid denominator.

# Function to calculate Peak Signal-to-Noise Ratio (PSNR) between two images
def calculate_psnr(original_image, normalized_image):
    """Calculate Peak Signal-to-Noise Ratio (PSNR)."""
    mse = np.mean((original_image.astype(np.float32) - normalized_image.astype(np.float32)) ** 2)  # Calculates MSE.
    return 10 * np.log10((255.0 ** 2) / mse) if mse != 0 else float('inf')  # Computes PSNR, handling zero MSE.

# Function to calculate Structural Similarity Index (SSIM) between two images
def calculate_ssim(original_image, normalized_image):
    """Calculate Structural Similarity Index (SSIM)."""
    original_image_gray = cv2.cvtColor(original_image, cv2.COLOR_RGB2GRAY)  # Converts original image to grayscale.
    normalized_image_gray = cv2.cvtColor(normalized_image, cv2.COLOR_RGB2GRAY)  # Converts normalized image to grayscale.
    original_image_gray = original_image_gray.astype(np.float64) / 255.0  # Normalizes pixel values to [0,1].
    normalized_image_gray = normalized_image_gray.astype(np.float64) / 255.0  # Normalizes pixel values to [0,1].
    return ssim(original_image_gray, normalized_image_gray, data_range=1.0)  # Computes SSIM between grayscale images.

# Main function to perform stain normalization on images in a directory
def normalize_stains(input_folder, output_folder, reference_image_url):
    """Normalize stains in images from the input folder using the reference image."""
    # Ensure output directory exists, creating it if necessary
    os.makedirs(output_folder, exist_ok=True)

    # Download reference image for normalization
    target_image = download_image(reference_image_url)  # Downloads and converts the reference image to array.

    # Initialize and fit the Macenko stain normalizer with the target image
    stain_normalizer = MacenkoNormalizer()  # Initializes Macenko Normalizer instance.
    stain_normalizer.fit(target_image)  # Fits the normalizer with the reference image for target stain profile.

    # Iterate over each image file in the input folder
    for filename in sorted(os.listdir(input_folder)):  # Sorts and loops over files in input folder.
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.tiff')):  # Processes only image files.
            source_path = os.path.join(input_folder, filename)  # Gets the full path of the source image.
            source_image = Image.open(source_path).convert("RGB")  # Opens and converts the image to RGB mode.
            sample = np.array(source_image)  # Converts image to numpy array.

            # Normalize the image using the Macenko Normalizer
            normed_sample = stain_normalizer.transform(sample.copy())  # Applies stain normalization.

            # Save the normalized image
            output_image = Image.fromarray(normed_sample.astype('uint8'))  # Converts array back to image format.
            output_path = os.path.join(output_folder, filename)  # Constructs output path.
            output_image.save(output_path)  # Saves normalized image to output folder.

            # Calculate image quality metrics
            pcc_value = calculate_pcc(sample, normed_sample)  # Calculates PCC between original and normalized images.
            amce_alpha_value = calculate_amce_alpha(target_image, normed_sample)  # Calculates AMCE-alpha.
            amce_beta_value = calculate_amce_beta(target_image, normed_sample)  # Calculates AMCE-beta.
            rse_value = calculate_rse(sample, normed_sample)  # Calculates RSE.
            psnr_value = calculate_psnr(sample, normed_sample)  # Calculates PSNR.
            ssim_value = calculate_ssim(sample, normed_sample)  # Calculates SSIM.

            # Print the metrics for each image
            print(f"Metrics for {filename}:")
            print(f"PCC: {pcc_value:.4f}")
            print(f"AMCE-alpha (Eα): {amce_alpha_value:.4f}")
            print(f"AMCE-beta (Eβ): {amce_beta_value:.4f}")
            print(f"RSE: {rse_value:.4f}")
            print(f"PSNR: {psnr_value:.4f}")
            print(f"SSIM: {ssim_value:.4f}")
            

# Example usage with folder paths and reference image URL (customize with your paths and URL)
input_folder = "/mnt/storage2/PanNuke/fold1/Thyroid/images"  # Define the input folder containing images.
output_folder = "/mnt/storage2/PanNuke/folder1/Mancenko_folder/M_Testis"  # Define the folder to save normalized images.
reference_image_url = "https://data.kitware.com/api/v1/file/57718cc28d777f1ecd8a883c/download"  # URL of the reference image.

# Run the normalization process
normalize_stains(input_folder, output_folder, reference_image_url)  # Calls the main function to process images.
# Out:
# Metrics for img_Testis_1_01411.png:
# PCC: 0.9896
# AMCE-alpha (Eα): 19.8370
# AMCE-beta (Eβ): 19.5612
# RSE: 0.0414
# PSNR: 17.1948
# SSIM: 0.9424
# --------------------------------------------------
# Metrics for img_Testis_1_01412.png:
# PCC: 0.9878
# AMCE-alpha (Eα): 31.1976
# AMCE-beta (Eβ): 33.7690
# RSE: 0.0503
# PSNR: 16.9003
# SSIM: 0.9337
# --------------------------------------------------
# Metrics for img_Testis_1_01413.png:
# PCC: 0.9929
# AMCE-alpha (Eα): 14.4370
# AMCE-beta (Eβ): 17.9189
# RSE: 0.0207
# PSNR: 20.6396
# SSIM: 0.9829
# --------------------------------------------------
# Metrics for img_Testis_1_01414.png:
# PCC: 0.9860
# AMCE-alpha (Eα): 16.9654
# AMCE-beta (Eβ): 14.6332
# RSE: 0.0261
# PSNR: 19.3690
# SSIM: 0.9477
# --------------------------------------------------
# Metrics for img_Testis_1_01415.png:
# PCC: 0.9854
# AMCE-alpha (Eα): 22.2486
# AMCE-beta (Eβ): 29.6420
# RSE: 0.0393
# PSNR: 17.9209
# SSIM: 0.9504
# --------------------------------------------------
# Metrics for img_Testis_1_01416.png:
# PCC: 0.9876
# AMCE-alpha (Eα): 8.7017
# AMCE-beta (Eβ): 13.4028
# RSE: 0.0374
# PSNR: 17.2702
# SSIM: 0.9427
# --------------------------------------------------
# Metrics for img_Testis_1_01417.png:
# PCC: 0.9834
# AMCE-alpha (Eα): 31.4536
# AMCE-beta (Eβ): 36.4739
# RSE: 0.0916
# PSNR: 13.6879
# SSIM: 0.8781
# --------------------------------------------------
# Metrics for img_Testis_1_01418.png:
# PCC: 0.9860
# AMCE-alpha (Eα): 13.4735
# AMCE-beta (Eβ): 27.0900
# RSE: 0.0434
# PSNR: 17.1178
# SSIM: 0.9512
# --------------------------------------------------
# Metrics for img_Testis_1_01419.png:
# PCC: 0.9695
# AMCE-alpha (Eα): 16.8964
# AMCE-beta (Eβ): 40.0962
# RSE: 0.0678
# PSNR: 15.3473
# SSIM: 0.9285
# --------------------------------------------------
# Metrics for img_Testis_1_01420.png:
# PCC: 0.9869
# AMCE-alpha (Eα): 18.1371
# AMCE-beta (Eβ): 21.1912
# RSE: 0.0612
# PSNR: 15.0927
# SSIM: 0.9101
# --------------------------------------------------
# Metrics for img_Testis_1_01421.png:
# PCC: 0.9724
# AMCE-alpha (Eα): 10.8030
# AMCE-beta (Eβ): 33.7514
# RSE: 0.0589
# PSNR: 15.6811
# SSIM: 0.9332
# --------------------------------------------------
# Metrics for img_Testis_1_01422.png:
# PCC: 0.9729
# AMCE-alpha (Eα): 17.3967
# AMCE-beta (Eβ): 38.8832
# RSE: 0.0685
# PSNR: 15.2725
# SSIM: 0.9298
# --------------------------------------------------
# Metrics for img_Testis_1_01423.png:
# PCC: 0.9895
# AMCE-alpha (Eα): 20.2385
# AMCE-beta (Eβ): 24.9213
# RSE: 0.0514
# PSNR: 16.2500
# SSIM: 0.9228
# --------------------------------------------------
# Metrics for img_Testis_1_01424.png:
# PCC: 0.9764
# AMCE-alpha (Eα): 12.0392
# AMCE-beta (Eβ): 31.7765
# RSE: 0.0610
# PSNR: 15.4844
# SSIM: 0.9335
# --------------------------------------------------
# Metrics for img_Testis_1_01425.png:
# PCC: 0.9923
# AMCE-alpha (Eα): 14.5671
# AMCE-beta (Eβ): 9.1771
# RSE: 0.0043
# PSNR: 27.4456
# SSIM: 0.9945
# --------------------------------------------------
# Metrics for img_Testis_1_01426.png:
# PCC: 0.9927
# AMCE-alpha (Eα): 3.1418
# AMCE-beta (Eβ): 12.6314
# RSE: 0.0120
# PSNR: 21.5588
# SSIM: 0.9565
# --------------------------------------------------
# Metrics for img_Testis_1_01427.png:
# PCC: 0.9946
# AMCE-alpha (Eα): 23.9328
# AMCE-beta (Eβ): 12.3977
# RSE: 0.0122
# PSNR: 22.6112
# SSIM: 0.9706
# --------------------------------------------------
# Metrics for img_Testis_1_01428.png:
# PCC: 0.9847
# AMCE-alpha (Eα): 32.4224
# AMCE-beta (Eβ): 33.6837
# RSE: 0.0217
# PSNR: 20.9665
# SSIM: 0.9502
# --------------------------------------------------
# Metrics for img_Testis_1_01429.png:
# PCC: 0.9955
# AMCE-alpha (Eα): 29.0408
# AMCE-beta (Eβ): 57.3718
# RSE: 0.0032
# PSNR: 26.1495
# SSIM: 0.9741
# --------------------------------------------------
# Metrics for img_Testis_1_01430.png:
# PCC: 0.9811
# AMCE-alpha (Eα): 25.8723
# AMCE-beta (Eβ): 56.1854
# RSE: 0.0180
# PSNR: 18.2152
# SSIM: 0.9372
# --------------------------------------------------
# Metrics for img_Testis_1_01431.png:
# PCC: 0.9930
# AMCE-alpha (Eα): 13.4023
# AMCE-beta (Eβ): 6.7184
# RSE: 0.0113
# PSNR: 22.7588
# SSIM: 0.9783
# --------------------------------------------------
# Metrics for img_Testis_1_01432.png:
# PCC: 0.9538
# AMCE-alpha (Eα): 9.8801
# AMCE-beta (Eβ): 16.4123
# RSE: 0.1071
# PSNR: 10.4936
# SSIM: 0.7508
# --------------------------------------------------
# Metrics for img_Testis_1_01433.png:
# PCC: 0.9494
# AMCE-alpha (Eα): 8.3047
# AMCE-beta (Eβ): 15.7514
# RSE: 0.1076
# PSNR: 10.4366
# SSIM: 0.8324
# --------------------------------------------------
# Metrics for img_Testis_1_01434.png:
# PCC: 0.9915
# AMCE-alpha (Eα): 12.2360
# AMCE-beta (Eβ): 31.6866
# RSE: 0.0074
# PSNR: 23.1083
# SSIM: 0.9685
# --------------------------------------------------
# Metrics for img_Testis_1_01435.png:
# PCC: 0.9861
# AMCE-alpha (Eα): 17.9827
# AMCE-beta (Eβ): 20.6052
# RSE: 0.0252
# PSNR: 19.4970
# SSIM: 0.9553
# --------------------------------------------------
# Metrics for img_Testis_1_01436.png:
# PCC: 0.9872
# AMCE-alpha (Eα): 14.8589
# AMCE-beta (Eβ): 15.3385
# RSE: 0.0175
# PSNR: 20.9373
# SSIM: 0.9610
# --------------------------------------------------
# Metrics for img_Testis_1_01437.png:
# PCC: 0.9972
# AMCE-alpha (Eα): 7.6752
# AMCE-beta (Eβ): 28.7682
# RSE: 0.0058
# PSNR: 24.3382
# SSIM: 0.9836
# --------------------------------------------------
# Metrics for img_Testis_1_01438.png:
# PCC: 0.9875
# AMCE-alpha (Eα): 13.9969
# AMCE-beta (Eβ): 11.8823
# RSE: 0.0142
# PSNR: 21.7856
# SSIM: 0.9581
# --------------------------------------------------
# Metrics for img_Testis_1_01439.png:
# PCC: 0.9914
# AMCE-alpha (Eα): 15.7346
# AMCE-beta (Eβ): 18.0866
# RSE: 0.0149
# PSNR: 21.9178
# SSIM: 0.9694
# --------------------------------------------------
# Metrics for img_Testis_1_01440.png:
# PCC: 0.9914
# AMCE-alpha (Eα): 12.0063
# AMCE-beta (Eβ): 10.4481
# RSE: 0.0101
# PSNR: 23.3839
# SSIM: 0.9720
# --------------------------------------------------
# Metrics for img_Testis_1_01441.png:
# PCC: 0.9950
# AMCE-alpha (Eα): 20.0220
# AMCE-beta (Eβ): 14.5660
# RSE: 0.0087
# PSNR: 24.4450
# SSIM: 0.9876
# --------------------------------------------------
# Metrics for img_Testis_1_01442.png:
# PCC: 0.9920
# AMCE-alpha (Eα): 26.9057
# AMCE-beta (Eβ): 26.2524
# RSE: 0.0111
# PSNR: 23.9644
# SSIM: 0.9765
# --------------------------------------------------
# Metrics for img_Testis_1_01443.png:
# PCC: 0.9763
# AMCE-alpha (Eα): 7.5191
# AMCE-beta (Eβ): 18.9579
# RSE: 0.0432
# PSNR: 16.5374
# SSIM: 0.9210
# --------------------------------------------------
# Metrics for img_Testis_1_01444.png:
# PCC: 0.9857
# AMCE-alpha (Eα): 32.2498
# AMCE-beta (Eβ): 40.4163
# RSE: 0.0320
# PSNR: 19.4565
# SSIM: 0.9479
# --------------------------------------------------
# Metrics for img_Testis_1_01445.png:
# PCC: 0.9930
# AMCE-alpha (Eα): 28.4175
# AMCE-beta (Eβ): 23.1385
# RSE: 0.0188
# PSNR: 21.4892
# SSIM: 0.9758
# --------------------------------------------------
# Metrics for img_Testis_1_02512.png:
# PCC: 0.9747
# AMCE-alpha (Eα): 48.6689
# AMCE-beta (Eβ): 44.4012
# RSE: 0.0318
# PSNR: 20.0615
# SSIM: 0.9283
# --------------------------------------------------
# Metrics for img_Testis_1_02513.png:
# PCC: 0.9619
# AMCE-alpha (Eα): 19.5757
# AMCE-beta (Eβ): 0.5086
# RSE: 0.0197
# PSNR: 20.3940
# SSIM: 0.8703
# --------------------------------------------------
# Metrics for img_Testis_1_02514.png:
# PCC: 0.9641
# AMCE-alpha (Eα): 35.5216
# AMCE-beta (Eβ): 21.5226
# RSE: 0.0265
# PSNR: 19.9234
# SSIM: 0.8932
# --------------------------------------------------
# Metrics for img_Testis_1_02515.png:
# PCC: 0.9686
# AMCE-alpha (Eα): 44.4824
# AMCE-beta (Eβ): 32.1103
# RSE: 0.0386
# PSNR: 18.4593
# SSIM: 0.8922
# --------------------------------------------------
# Metrics for img_Testis_1_02516.png:
# PCC: 0.9611
# AMCE-alpha (Eα): 20.1494
# AMCE-beta (Eβ): 0.4636
# RSE: 0.0199
# PSNR: 20.3764
# SSIM: 0.8859
# --------------------------------------------------
# Metrics for img_Testis_1_02517.png:
# PCC: 0.9806
# AMCE-alpha (Eα): 9.9594
# AMCE-beta (Eβ): 21.2152
# RSE: 0.0777
# PSNR: 13.9958
# SSIM: 0.8895
# --------------------------------------------------
# Metrics for img_Testis_1_02518.png:
# PCC: 0.9841
# AMCE-alpha (Eα): 17.9117
# AMCE-beta (Eβ): 19.0337
# RSE: 0.0900
# PSNR: 12.6007
# SSIM: 0.9069
# --------------------------------------------------
# Metrics for img_Testis_1_02519.png:
# PCC: 0.9805
# AMCE-alpha (Eα): 22.9075
# AMCE-beta (Eβ): 30.5292
# RSE: 0.0925
# PSNR: 13.5874
# SSIM: 0.8439
# --------------------------------------------------
# Metrics for img_Testis_1_02520.png:
# PCC: 0.9804
# AMCE-alpha (Eα): 0.6276
# AMCE-beta (Eβ): 7.9050
# RSE: 0.0646
# PSNR: 14.2596
# SSIM: 0.8776
# --------------------------------------------------
# Metrics for img_Testis_1_02521.png:
# PCC: 0.9613
# AMCE-alpha (Eα): 14.3848
# AMCE-beta (Eβ): 9.9110
# RSE: 0.0189
# PSNR: 19.9823
# SSIM: 0.9924
# --------------------------------------------------
# Metrics for img_Testis_1_02522.png:
# PCC: 0.9830
# AMCE-alpha (Eα): 35.3324
# AMCE-beta (Eβ): 34.7007
# RSE: 0.1069
# PSNR: 12.7926
# SSIM: 0.8371
# --------------------------------------------------
# Metrics for img_Testis_1_02523.png:
# PCC: 0.9841
# AMCE-alpha (Eα): 32.3950
# AMCE-beta (Eβ): 32.4530
# RSE: 0.0826
# PSNR: 14.2157
# SSIM: 0.8821
# --------------------------------------------------
# Metrics for img_Testis_1_02524.png:
# PCC: 0.9835
# AMCE-alpha (Eα): 33.3188
# AMCE-beta (Eβ): 31.8046
# RSE: 0.0969
# PSNR: 13.1886
# SSIM: 0.8625
# --------------------------------------------------
# Metrics for img_Testis_1_02525.png:
# PCC: 0.9874
# AMCE-alpha (Eα): 42.9372
# AMCE-beta (Eβ): 47.9290
# RSE: 0.0244
# PSNR: 21.9008
# SSIM: 0.9944
# --------------------------------------------------
# Metrics for img_Testis_1_02526.png:
# PCC: 0.9864
# AMCE-alpha (Eα): 42.5352
# AMCE-beta (Eβ): 49.0893
# RSE: 0.0222
# PSNR: 22.4425
# SSIM: 0.9955
# --------------------------------------------------
# Metrics for img_Testis_1_02527.png:
# PCC: 0.9721
# AMCE-alpha (Eα): 23.1726
# AMCE-beta (Eβ): 40.2899
# RSE: 0.0436
# PSNR: 17.9320
# SSIM: 0.9672
# --------------------------------------------------
# Metrics for img_Testis_1_02528.png:
# PCC: 0.9869
# AMCE-alpha (Eα): 42.6140
# AMCE-beta (Eβ): 53.1810
# RSE: 0.0341
# PSNR: 20.5388
# SSIM: 0.9909
# --------------------------------------------------
# Metrics for img_Testis_1_02529.png:
# PCC: 0.9843
# AMCE-alpha (Eα): 31.2077
# AMCE-beta (Eβ): 44.1176
# RSE: 0.0401
# PSNR: 18.8754
# SSIM: 0.9812
# --------------------------------------------------
# Metrics for img_Testis_1_02530.png:
# PCC: 0.9797
# AMCE-alpha (Eα): 33.5955
# AMCE-beta (Eβ): 45.7789
# RSE: 0.0390
# PSNR: 19.2641
# SSIM: 0.9842
# --------------------------------------------------
# Metrics for img_Testis_1_02531.png:
# PCC: 0.9797
# AMCE-alpha (Eα): 44.8264
# AMCE-beta (Eβ): 48.0706
# RSE: 0.0805
# PSNR: 15.6800
# SSIM: 0.8988
# --------------------------------------------------
# Metrics for img_Testis_1_02532.png:
# PCC: 0.9848
# AMCE-alpha (Eα): 45.1478
# AMCE-beta (Eβ): 50.3995
# RSE: 0.0781
# PSNR: 15.9081
# SSIM: 0.9313
# --------------------------------------------------
# Metrics for img_Testis_1_02533.png:
# PCC: 0.9871
# AMCE-alpha (Eα): 46.1380
# AMCE-beta (Eβ): 45.6705
# RSE: 0.0727
# PSNR: 16.0219
# SSIM: 0.9225
# --------------------------------------------------
# Metrics for img_Testis_1_02534.png:
# PCC: 0.9865
# AMCE-alpha (Eα): 40.9274
# AMCE-beta (Eβ): 49.9752
# RSE: 0.0717
# PSNR: 16.2050
# SSIM: 0.9287
# --------------------------------------------------
# Metrics for img_Testis_1_02535.png:
# PCC: 0.9901
# AMCE-alpha (Eα): 42.6920
# AMCE-beta (Eβ): 42.5610
# RSE: 0.0610
# PSNR: 16.6746
# SSIM: 0.9267
# --------------------------------------------------
# Metrics for img_Testis_1_02536.png:
# PCC: 0.9809
# AMCE-alpha (Eα): 40.4214
# AMCE-beta (Eβ): 35.0141
# RSE: 0.0457
# PSNR: 18.1495
# SSIM: 0.9229
# --------------------------------------------------

# %%
# Import necessary libraries for working with images, downloading data, and performing various metrics
import os
import requests
import numpy as np
from PIL import Image
from io import BytesIO
from tiatoolbox.tools.stainnorm import VahadaneNormalizer  # Updated to Vahadane for stain normalization
import cv2
from skimage.metrics import structural_similarity as ssim
from scipy.stats import pearsonr

# Function to download an image from a URL
def download_image(image_url):
    """Download an image from a given URL."""
    response = requests.get(image_url)  # Send HTTP GET request to the URL
    response.raise_for_status()  # Raise error if the response has issues
    img = Image.open(BytesIO(response.content)).convert("RGB")  # Convert the response content into an RGB image
    return np.array(img)  # Return the image as a NumPy array

# Function to calculate Pearson Correlation Coefficient (PCC) for each color channel
def calculate_pcc(original_image, normalized_image):
    """Calculate Pearson Correlation Coefficient (PCC) for each color channel."""
    # Calculate PCC for the red, green, and blue channels individually
    pcc_r = pearsonr(original_image[:, :, 0].flatten(), normalized_image[:, :, 0].flatten())[0]
    pcc_g = pearsonr(original_image[:, :, 1].flatten(), normalized_image[:, :, 1].flatten())[0]
    pcc_b = pearsonr(original_image[:, :, 2].flatten(), normalized_image[:, :, 2].flatten())[0]
    # Return the average PCC over RGB channels
    return (pcc_r + pcc_g + pcc_b) / 3  

# Function to calculate the AMCE-alpha metric (Eα)
def calculate_amce_alpha(target_image, processed_image):
    """Calculate AMCE-alpha (Eα)."""
    # Compute mean of the alpha channel (assumed to be the Red channel here) in both images
    mean_target_alpha = np.mean(target_image[:, :, 0])  
    mean_processed_alpha = np.mean(processed_image[:, :, 0])
    # Return the absolute difference as AMCE-alpha
    return abs(mean_target_alpha - mean_processed_alpha)

# Function to calculate the AMCE-beta metric (Eβ)
def calculate_amce_beta(target_image, processed_image):
    """Calculate AMCE-beta (Eβ)."""
    # Compute mean of the beta channel (assumed to be the Blue channel here) in both images
    mean_target_beta = np.mean(target_image[:, :, 2])  
    mean_processed_beta = np.mean(processed_image[:, :, 2])
    # Return the absolute difference as AMCE-beta
    return abs(mean_target_beta - mean_processed_beta)

# Function to calculate Relative Square Error (RSE)
def calculate_rse(original_image, normalized_image):
    """Calculate Relative Square Error (RSE)."""
    # Calculate squared difference between original and normalized images
    diff = original_image.astype(np.float32) - normalized_image.astype(np.float32)
    squared_error = np.sum(diff ** 2)
    # Compute the squared sum of the original image
    original_squared_sum = np.sum(original_image.astype(np.float32) ** 2)
    # Return RSE if original squared sum is non-zero
    return squared_error / original_squared_sum if original_squared_sum != 0 else 0

# Function to calculate Peak Signal-to-Noise Ratio (PSNR)
def calculate_psnr(original_image, normalized_image):
    """Calculate Peak Signal-to-Noise Ratio (PSNR)."""
    # Calculate mean squared error between original and normalized images
    mse = np.mean((original_image.astype(np.float32) - normalized_image.astype(np.float32)) ** 2)
    # Return PSNR value using formula
    return 10 * np.log10((255.0 ** 2) / mse) if mse != 0 else float('inf')

# Function to calculate Structural Similarity Index (SSIM)
def calculate_ssim(original_image, normalized_image):
    """Calculate Structural Similarity Index (SSIM)."""
    # Convert both images to grayscale for SSIM calculation
    original_image_gray = cv2.cvtColor(original_image, cv2.COLOR_RGB2GRAY)
    normalized_image_gray = cv2.cvtColor(normalized_image, cv2.COLOR_RGB2GRAY)
    # Normalize the grayscale images to [0, 1]
    original_image_gray = original_image_gray.astype(np.float64) / 255.0
    normalized_image_gray = normalized_image_gray.astype(np.float64) / 255.0
    # Calculate and return SSIM
    return ssim(original_image_gray, normalized_image_gray, data_range=1.0)

# Function to normalize stains for images in a folder using a reference image
def normalize_stains(input_folder, output_folder, reference_image_url):
    """Normalize stains in images from the input folder using the reference image."""
    # Create output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    # Download the reference image and convert to array
    target_image = download_image(reference_image_url)

    # Initialize the Vahadane Normalizer
    stain_normalizer = VahadaneNormalizer()  # Updated to Vahadane normalization
    # Fit the normalizer with the target image
    stain_normalizer.fit(target_image)

    # Loop through each image in the input folder
    for filename in sorted(os.listdir(input_folder)):
        # Process only files with specific image extensions
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.tiff')):
            source_path = os.path.join(input_folder, filename)  # Get path to the source image
            source_image = Image.open(source_path).convert("RGB")  # Open and convert image to RGB
            sample = np.array(source_image)  # Convert image to NumPy array

            # Normalize the image using the Vahadane Normalizer
            normed_sample = stain_normalizer.transform(sample.copy())

            # Save the normalized image
            output_image = Image.fromarray(normed_sample.astype('uint8'))
            output_path = os.path.join(output_folder, filename)  # Define output path for normalized image
            output_image.save(output_path)  # Save image in the output folder

            # Calculate metrics for the image
            pcc_value = calculate_pcc(sample, normed_sample)
            amce_alpha_value = calculate_amce_alpha(target_image, normed_sample)
            amce_beta_value = calculate_amce_beta(target_image, normed_sample)
            rse_value = calculate_rse(sample, normed_sample)
            psnr_value = calculate_psnr(sample, normed_sample)
            ssim_value = calculate_ssim(sample, normed_sample)

            # Print calculated metrics for the current image
            print(f"Metrics for {filename}:")
            print(f"PCC: {pcc_value:.4f}")
            print(f"AMCE-alpha (Eα): {amce_alpha_value:.4f}")
            print(f"AMCE-beta (Eβ): {amce_beta_value:.4f}")
            print(f"RSE: {rse_value:.4f}")
            print(f"PSNR: {psnr_value:.4f}")
            print(f"SSIM: {ssim_value:.4f}")
            

# Example usage
input_folder = "/mnt/storage2/PanNuke/fold1/Thyroid/images"  # Specify your input folder path here
output_folder = "/mnt/storage2/PanNuke/folder1/vahadane_folder/V_Testis"  # Specify your output folder path here
reference_image_url = "https://data.kitware.com/api/v1/file/57718cc28d777f1ecd8a883c/download"  # Reference image URL

normalize_stains(input_folder, output_folder, reference_image_url)
# Out:
# Metrics for img_Testis_1_01411.png:
# PCC: 0.9793
# AMCE-alpha (Eα): 4.0926
# AMCE-beta (Eβ): 2.7989
# RSE: 0.0181
# PSNR: 20.7866
# SSIM: 0.9729
# --------------------------------------------------
# Metrics for img_Testis_1_01412.png:
# PCC: 0.9863
# AMCE-alpha (Eα): 14.2178
# AMCE-beta (Eβ): 13.2068
# RSE: 0.0170
# PSNR: 21.6051
# SSIM: 0.9784
# --------------------------------------------------
# Metrics for img_Testis_1_01413.png:
# PCC: 0.9872
# AMCE-alpha (Eα): 0.4162
# AMCE-beta (Eβ): 2.0854
# RSE: 0.0100
# PSNR: 23.7945
# SSIM: 0.9936
# --------------------------------------------------
# Metrics for img_Testis_1_01414.png:
# PCC: 0.9900
# AMCE-alpha (Eα): 15.4319
# AMCE-beta (Eβ): 18.8666
# RSE: 0.0336
# PSNR: 18.2616
# SSIM: 0.9573
# --------------------------------------------------
# Metrics for img_Testis_1_01415.png:
# PCC: 0.9928
# AMCE-alpha (Eα): 11.4515
# AMCE-beta (Eβ): 13.6054
# RSE: 0.0148
# PSNR: 22.1530
# SSIM: 0.9821
# --------------------------------------------------
# Metrics for img_Testis_1_01416.png:
# PCC: 0.9916
# AMCE-alpha (Eα): 0.0140
# AMCE-beta (Eβ): 0.1204
# RSE: 0.0182
# PSNR: 20.4123
# SSIM: 0.9716
# --------------------------------------------------
# Metrics for img_Testis_1_01417.png:
# PCC: 0.9830
# AMCE-alpha (Eα): 18.3815
# AMCE-beta (Eβ): 22.0935
# RSE: 0.0556
# PSNR: 15.8543
# SSIM: 0.9184
# --------------------------------------------------
# Metrics for img_Testis_1_01418.png:
# PCC: 0.9927
# AMCE-alpha (Eα): 3.1219
# AMCE-beta (Eβ): 5.2945
# RSE: 0.0123
# PSNR: 22.5758
# SSIM: 0.9852
# --------------------------------------------------
# Metrics for img_Testis_1_01419.png:
# PCC: 0.9895
# AMCE-alpha (Eα): 6.4280
# AMCE-beta (Eβ): 16.4631
# RSE: 0.0233
# PSNR: 19.9913
# SSIM: 0.9743
# --------------------------------------------------
# Metrics for img_Testis_1_01420.png:
# PCC: 0.9864
# AMCE-alpha (Eα): 8.5598
# AMCE-beta (Eβ): 10.3092
# RSE: 0.0396
# PSNR: 16.9880
# SSIM: 0.9373
# --------------------------------------------------
# Metrics for img_Testis_1_01421.png:
# PCC: 0.9933
# AMCE-alpha (Eα): 1.9541
# AMCE-beta (Eβ): 6.3130
# RSE: 0.0144
# PSNR: 21.7902
# SSIM: 0.9819
# --------------------------------------------------
# Metrics for img_Testis_1_01422.png:
# PCC: 0.9902
# AMCE-alpha (Eα): 5.0926
# AMCE-beta (Eβ): 11.7578
# RSE: 0.0191
# PSNR: 20.8249
# SSIM: 0.9786
# --------------------------------------------------
# Metrics for img_Testis_1_01423.png:
# PCC: 0.9889
# AMCE-alpha (Eα): 14.6467
# AMCE-beta (Eβ): 20.7214
# RSE: 0.0441
# PSNR: 16.9108
# SSIM: 0.9393
# --------------------------------------------------
# Metrics for img_Testis_1_01424.png:
# PCC: 0.9917
# AMCE-alpha (Eα): 0.7991
# AMCE-beta (Eβ): 3.8482
# RSE: 0.0150
# PSNR: 21.5873
# SSIM: 0.9811
# --------------------------------------------------
# Metrics for img_Testis_1_01425.png:
# PCC: 0.7581
# AMCE-alpha (Eα): 14.4111
# AMCE-beta (Eβ): 61.9049
# RSE: 0.1592
# PSNR: 11.8031
# SSIM: 0.7547
# --------------------------------------------------
# Metrics for img_Testis_1_01426.png:
# PCC: 0.9899
# AMCE-alpha (Eα): 12.1955
# AMCE-beta (Eβ): 26.0555
# RSE: 0.0055
# PSNR: 24.9479
# SSIM: 0.9901
# --------------------------------------------------
# Metrics for img_Testis_1_01427.png:
# PCC: 0.9930
# AMCE-alpha (Eα): 8.0578
# AMCE-beta (Eβ): 2.8024
# RSE: 0.0063
# PSNR: 25.4805
# SSIM: 0.9926
# --------------------------------------------------
# Metrics for img_Testis_1_01428.png:
# PCC: 0.9958
# AMCE-alpha (Eα): 15.7984
# AMCE-beta (Eβ): 11.0469
# RSE: 0.0036
# PSNR: 28.7728
# SSIM: 0.9978
# --------------------------------------------------
# Metrics for img_Testis_1_01429.png:
# PCC: 0.9897
# AMCE-alpha (Eα): 34.7424
# AMCE-beta (Eβ): 65.3902
# RSE: 0.0018
# PSNR: 28.7145
# SSIM: 0.9920
# --------------------------------------------------
# Metrics for img_Testis_1_01430.png:
# PCC: 0.9658
# AMCE-alpha (Eα): 27.2416
# AMCE-beta (Eβ): 75.4411
# RSE: 0.0071
# PSNR: 22.2231
# SSIM: 0.9709
# --------------------------------------------------
# Metrics for img_Testis_1_01431.png:
# PCC: 0.9967
# AMCE-alpha (Eα): 3.0078
# AMCE-beta (Eβ): 6.0425
# RSE: 0.0026
# PSNR: 29.1239
# SSIM: 0.9969
# --------------------------------------------------
# Metrics for img_Testis_1_01432.png:
# PCC: 0.9535
# AMCE-alpha (Eα): 5.5502
# AMCE-beta (Eβ): 48.0313
# RSE: 0.0594
# PSNR: 13.0526
# SSIM: 0.8389
# --------------------------------------------------
# Metrics for img_Testis_1_01433.png:
# PCC: 0.9581
# AMCE-alpha (Eα): 2.5680
# AMCE-beta (Eβ): 44.5192
# RSE: 0.0597
# PSNR: 12.9918
# SSIM: 0.8842
# --------------------------------------------------
# Metrics for img_Testis_1_01434.png:
# PCC: 0.9951
# AMCE-alpha (Eα): 22.1718
# AMCE-beta (Eβ): 44.0121
# RSE: 0.0018
# PSNR: 29.2231
# SSIM: 0.9974
# --------------------------------------------------
# Metrics for img_Testis_1_01435.png:
# PCC: 0.9947
# AMCE-alpha (Eα): 6.4162
# AMCE-beta (Eβ): 4.7336
# RSE: 0.0061
# PSNR: 25.6642
# SSIM: 0.9904
# --------------------------------------------------
# Metrics for img_Testis_1_01436.png:
# PCC: 0.9960
# AMCE-alpha (Eα): 0.4373
# AMCE-beta (Eβ): 6.4899
# RSE: 0.0023
# PSNR: 29.6926
# SSIM: 0.9981
# --------------------------------------------------
# Metrics for img_Testis_1_01437.png:
# PCC: 0.9850
# AMCE-alpha (Eα): 20.5609
# AMCE-beta (Eβ): 39.4048
# RSE: 0.0058
# PSNR: 24.3756
# SSIM: 0.9821
# --------------------------------------------------
# Metrics for img_Testis_1_01438.png:
# PCC: 0.9955
# AMCE-alpha (Eα): 2.2909
# AMCE-beta (Eβ): 12.2729
# RSE: 0.0042
# PSNR: 27.0345
# SSIM: 0.9928
# --------------------------------------------------
# Metrics for img_Testis_1_01439.png:
# PCC: 0.9941
# AMCE-alpha (Eα): 0.9238
# AMCE-beta (Eβ): 3.1733
# RSE: 0.0048
# PSNR: 26.8199
# SSIM: 0.9957
# --------------------------------------------------
# Metrics for img_Testis_1_01440.png:
# PCC: 0.9961
# AMCE-alpha (Eα): 2.1535
# AMCE-beta (Eβ): 9.2319
# RSE: 0.0031
# PSNR: 28.4425
# SSIM: 0.9956
# --------------------------------------------------
# Metrics for img_Testis_1_01441.png:
# PCC: 0.9945
# AMCE-alpha (Eα): 5.6695
# AMCE-beta (Eβ): 0.2284
# RSE: 0.0042
# PSNR: 27.5541
# SSIM: 0.9970
# --------------------------------------------------
# Metrics for img_Testis_1_01442.png:
# PCC: 0.9926
# AMCE-alpha (Eα): 8.3678
# AMCE-beta (Eβ): 6.5928
# RSE: 0.0110
# PSNR: 23.9759
# SSIM: 0.9874
# --------------------------------------------------
# Metrics for img_Testis_1_01443.png:
# PCC: 0.7804
# AMCE-alpha (Eα): 1.4427
# AMCE-beta (Eβ): 76.0352
# RSE: 0.0900
# PSNR: 13.3515
# SSIM: 0.7370
# --------------------------------------------------
# Metrics for img_Testis_1_01444.png:
# PCC: 0.9928
# AMCE-alpha (Eα): 10.0090
# AMCE-beta (Eβ): 14.7023
# RSE: 0.0065
# PSNR: 26.3883
# SSIM: 0.9959
# --------------------------------------------------
# Metrics for img_Testis_1_01445.png:
# PCC: 0.9935
# AMCE-alpha (Eα): 16.9392
# AMCE-beta (Eβ): 16.5157
# RSE: 0.0107
# PSNR: 23.9440
# SSIM: 0.9876
# --------------------------------------------------
# Metrics for img_Testis_1_02512.png:
# PCC: 0.9842
# AMCE-alpha (Eα): 37.6084
# AMCE-beta (Eβ): 43.1446
# RSE: 0.0159
# PSNR: 23.0582
# SSIM: 0.9864
# --------------------------------------------------
# Metrics for img_Testis_1_02513.png:
# PCC: 0.9901
# AMCE-alpha (Eα): 13.9081
# AMCE-beta (Eβ): 6.2565
# RSE: 0.0085
# PSNR: 24.0445
# SSIM: 0.9860
# --------------------------------------------------
# Metrics for img_Testis_1_02514.png:
# PCC: 0.9867
# AMCE-alpha (Eα): 27.4156
# AMCE-beta (Eβ): 17.7900
# RSE: 0.0132
# PSNR: 22.9606
# SSIM: 0.9831
# --------------------------------------------------
# Metrics for img_Testis_1_02515.png:
# PCC: 0.9846
# AMCE-alpha (Eα): 31.4556
# AMCE-beta (Eβ): 22.1417
# RSE: 0.0155
# PSNR: 22.4282
# SSIM: 0.9786
# --------------------------------------------------
# Metrics for img_Testis_1_02516.png:
# PCC: 0.9899
# AMCE-alpha (Eα): 16.6506
# AMCE-beta (Eβ): 4.3132
# RSE: 0.0121
# PSNR: 22.5451
# SSIM: 0.9789
# --------------------------------------------------
# Metrics for img_Testis_1_02517.png:
# PCC: 0.7695
# AMCE-alpha (Eα): 40.3934
# AMCE-beta (Eβ): 22.4114
# RSE: 0.0593
# PSNR: 15.1671
# SSIM: 0.9042
# --------------------------------------------------
# Metrics for img_Testis_1_02518.png:
# PCC: 0.7779
# AMCE-alpha (Eα): 55.0423
# AMCE-beta (Eβ): 57.6243
# RSE: 0.0787
# PSNR: 13.1865
# SSIM: 0.9091
# --------------------------------------------------
# Metrics for img_Testis_1_02519.png:
# PCC: 0.9790
# AMCE-alpha (Eα): 10.0181
# AMCE-beta (Eβ): 18.5411
# RSE: 0.0666
# PSNR: 15.0146
# SSIM: 0.9093
# --------------------------------------------------
# Metrics for img_Testis_1_02520.png:
# PCC: 0.8002
# AMCE-alpha (Eα): 32.9669
# AMCE-beta (Eβ): 36.0359
# RSE: 0.0524
# PSNR: 15.1660
# SSIM: 0.9172
# --------------------------------------------------
# Metrics for img_Testis_1_02521.png:
# PCC: 0.8881
# AMCE-alpha (Eα): 24.3944
# AMCE-beta (Eβ): 45.4702
# RSE: 0.0215
# PSNR: 19.4188
# SSIM: 0.9756
# --------------------------------------------------
# Metrics for img_Testis_1_02522.png:
# PCC: 0.9759
# AMCE-alpha (Eα): 18.9919
# AMCE-beta (Eβ): 21.7165
# RSE: 0.0697
# PSNR: 14.6524
# SSIM: 0.8970
# --------------------------------------------------
# Metrics for img_Testis_1_02523.png:
# PCC: 0.9763
# AMCE-alpha (Eα): 17.7946
# AMCE-beta (Eβ): 21.1860
# RSE: 0.0541
# PSNR: 16.0505
# SSIM: 0.9275
# --------------------------------------------------
# Metrics for img_Testis_1_02524.png:
# PCC: 0.9802
# AMCE-alpha (Eα): 17.4854
# AMCE-beta (Eβ): 20.2887
# RSE: 0.0641
# PSNR: 14.9854
# SSIM: 0.9056
# --------------------------------------------------
# Metrics for img_Testis_1_02525.png:
# PCC: 0.9865
# AMCE-alpha (Eα): 24.6299
# AMCE-beta (Eβ): 30.0028
# RSE: 0.0252
# PSNR: 21.7666
# SSIM: 0.9870
# --------------------------------------------------
# Metrics for img_Testis_1_02526.png:
# PCC: 0.9875
# AMCE-alpha (Eα): 29.9352
# AMCE-beta (Eβ): 32.4892
# RSE: 0.0158
# PSNR: 23.9129
# SSIM: 0.9943
# --------------------------------------------------
# Metrics for img_Testis_1_02527.png:
# PCC: 0.9872
# AMCE-alpha (Eα): 8.4150
# AMCE-beta (Eβ): 14.6720
# RSE: 0.0105
# PSNR: 24.1274
# SSIM: 0.9962
# --------------------------------------------------
# Metrics for img_Testis_1_02528.png:
# PCC: 0.9863
# AMCE-alpha (Eα): 23.0994
# AMCE-beta (Eβ): 33.1719
# RSE: 0.0275
# PSNR: 21.4739
# SSIM: 0.9881
# --------------------------------------------------
# Metrics for img_Testis_1_02529.png:
# PCC: 0.9863
# AMCE-alpha (Eα): 16.2164
# AMCE-beta (Eβ): 26.8553
# RSE: 0.0211
# PSNR: 21.6732
# SSIM: 0.9917
# --------------------------------------------------
# Metrics for img_Testis_1_02530.png:
# PCC: 0.9840
# AMCE-alpha (Eα): 19.0416
# AMCE-beta (Eβ): 28.7374
# RSE: 0.0216
# PSNR: 21.8334
# SSIM: 0.9917
# --------------------------------------------------
# Metrics for img_Testis_1_02531.png:
# PCC: 0.9671
# AMCE-alpha (Eα): 27.2250
# AMCE-beta (Eβ): 32.9056
# RSE: 0.0482
# PSNR: 17.9032
# SSIM: 0.9508
# --------------------------------------------------
# Metrics for img_Testis_1_02532.png:
# PCC: 0.9743
# AMCE-alpha (Eα): 23.2472
# AMCE-beta (Eβ): 28.6811
# RSE: 0.0356
# PSNR: 19.3143
# SSIM: 0.9688
# --------------------------------------------------
# Metrics for img_Testis_1_02533.png:
# PCC: 0.9766
# AMCE-alpha (Eα): 25.8895
# AMCE-beta (Eβ): 28.2244
# RSE: 0.0357
# PSNR: 19.1090
# SSIM: 0.9621
# --------------------------------------------------
# Metrics for img_Testis_1_02534.png:
# PCC: 0.9796
# AMCE-alpha (Eα): 23.2967
# AMCE-beta (Eβ): 33.8261
# RSE: 0.0388
# PSNR: 18.8792
# SSIM: 0.9604
# --------------------------------------------------
# Metrics for img_Testis_1_02535.png:
# PCC: 0.9782
# AMCE-alpha (Eα): 23.3602
# AMCE-beta (Eβ): 30.0201
# RSE: 0.0382
# PSNR: 18.7083
# SSIM: 0.9603
# --------------------------------------------------
# Metrics for img_Testis_1_02536.png:
# PCC: 0.9736
# AMCE-alpha (Eα): 28.1128
# AMCE-beta (Eβ): 34.7219
# RSE: 0.0468
# PSNR: 18.0476
# SSIM: 0.9549
# --------------------------------------------------

# %%
# Import necessary libraries for image processing, stain normalization, and metrics calculation
import os  # For interacting with the operating system
import requests  # To handle HTTP requests and download images
import numpy as np  # For numerical operations on image data
from PIL import Image  # To handle image processing
from io import BytesIO  # For in-memory binary I/O operations
from tiatoolbox.tools.stainnorm import RuifrokNormalizer  # Import Ruifrok stain normalization tool from tiatoolbox
import cv2  # OpenCV library for image processing
from skimage.metrics import structural_similarity as ssim  # For calculating structural similarity between images
from scipy.stats import pearsonr  # For calculating Pearson correlation coefficient

def download_image(image_url):
    """Download an image from a given URL."""
    response = requests.get(image_url)  # Send HTTP request to download the image
    response.raise_for_status()  # Raise an error if the request fails
    img = Image.open(BytesIO(response.content)).convert("RGB")  # Open the image and convert it to RGB format
    return np.array(img)  # Convert the image to a numpy array and return it

def calculate_pcc(original_image, normalized_image):
    """Calculate Pearson Correlation Coefficient (PCC) for each color channel."""
    pcc_r = pearsonr(original_image[:, :, 0].flatten(), normalized_image[:, :, 0].flatten())[0]  # PCC for red channel
    pcc_g = pearsonr(original_image[:, :, 1].flatten(), normalized_image[:, :, 1].flatten())[0]  # PCC for green channel
    pcc_b = pearsonr(original_image[:, :, 2].flatten(), normalized_image[:, :, 2].flatten())[0]  # PCC for blue channel
    return (pcc_r + pcc_g + pcc_b) / 3  # Return the average PCC across all channels

def calculate_amce_alpha(target_image, processed_image):
    """Calculate AMCE-alpha (Eα) by measuring absolute difference in mean red values."""
    mean_target_alpha = np.mean(target_image[:, :, 0])  # Calculate mean for the red channel in target image
    mean_processed_alpha = np.mean(processed_image[:, :, 0])  # Calculate mean for red channel in processed image
    return abs(mean_target_alpha - mean_processed_alpha)  # Return absolute difference in means

def calculate_amce_beta(target_image, processed_image):
    """Calculate AMCE-beta (Eβ) by measuring absolute difference in mean blue values."""
    mean_target_beta = np.mean(target_image[:, :, 2])  # Calculate mean for the blue channel in target image
    mean_processed_beta = np.mean(processed_image[:, :, 2])  # Calculate mean for blue channel in processed image
    return abs(mean_target_beta - mean_processed_beta)  # Return absolute difference in means

def calculate_rse(original_image, normalized_image):
    """Calculate Relative Square Error (RSE) between original and normalized images."""
    diff = original_image.astype(np.float32) - normalized_image.astype(np.float32)  # Difference between images
    squared_error = np.sum(diff ** 2)  # Sum of squared errors across all pixels
    original_squared_sum = np.sum(original_image.astype(np.float32) ** 2)  # Total squared value of original image
    return squared_error / original_squared_sum if original_squared_sum != 0 else 0  # Return RSE

def calculate_psnr(original_image, normalized_image):
    """Calculate Peak Signal-to-Noise Ratio (PSNR) between original and normalized images."""
    mse = np.mean((original_image.astype(np.float32) - normalized_image.astype(np.float32)) ** 2)  # Mean squared error
    return 10 * np.log10((255.0 ** 2) / mse) if mse != 0 else float('inf')  # Return PSNR or infinity if MSE is zero

def calculate_ssim(original_image, normalized_image):
    """Calculate Structural Similarity Index (SSIM) between grayscale versions of images."""
    original_image_gray = cv2.cvtColor(original_image, cv2.COLOR_RGB2GRAY)  # Convert original image to grayscale
    normalized_image_gray = cv2.cvtColor(normalized_image, cv2.COLOR_RGB2GRAY)  # Convert normalized image to grayscale
    original_image_gray = original_image_gray.astype(np.float64) / 255.0  # Normalize pixel values to [0, 1]
    normalized_image_gray = normalized_image_gray.astype(np.float64) / 255.0  # Normalize pixel values to [0, 1]
    return ssim(original_image_gray, normalized_image_gray, data_range=1.0)  # Calculate SSIM

def normalize_stains(input_folder, output_folder, reference_image_url):
    """Normalize stains in images from the input folder using the reference image."""
    os.makedirs(output_folder, exist_ok=True)  # Create output folder if it doesn't exist

    target_image = download_image(reference_image_url)  # Download and convert the reference image to an array

    stain_normalizer = RuifrokNormalizer()  # Initialize the Ruifrok stain normalizer
    stain_normalizer.fit(target_image)  # Fit the normalizer with the reference image

    for filename in sorted(os.listdir(input_folder)):  # Loop through sorted files in the input folder
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.tiff')):  # Process only image files
            source_path = os.path.join(input_folder, filename)  # Full path to the image file
            source_image = Image.open(source_path).convert("RGB")  # Open and convert the source image to RGB
            sample = np.array(source_image)  # Convert the image to a numpy array

            normed_sample = stain_normalizer.transform(sample.copy())  # Normalize the image using Ruifrok Normalizer

            output_image = Image.fromarray(normed_sample.astype('uint8'))  # Convert normalized array back to an image
            output_path = os.path.join(output_folder, filename)  # Path to save the normalized image
            output_image.save(output_path)  # Save the normalized image

            # Calculate metrics to assess quality of stain normalization
            pcc_value = calculate_pcc(sample, normed_sample)  # Calculate Pearson Correlation Coefficient (PCC)
            amce_alpha_value = calculate_amce_alpha(target_image, normed_sample)  # Calculate AMCE-alpha
            amce_beta_value = calculate_amce_beta(target_image, normed_sample)  # Calculate AMCE-beta
            rse_value = calculate_rse(sample, normed_sample)  # Calculate Relative Square Error (RSE)
            psnr_value = calculate_psnr(sample, normed_sample)  # Calculate Peak Signal-to-Noise Ratio (PSNR)
            ssim_value = calculate_ssim(sample, normed_sample)  # Calculate Structural Similarity Index (SSIM)

            # Display the calculated metrics for each image
            print(f"Metrics for {filename}:")
            print(f"PCC: {pcc_value:.4f}")
            print(f"AMCE-alpha (Eα): {amce_alpha_value:.4f}")
            print(f"AMCE-beta (Eβ): {amce_beta_value:.4f}")
            print(f"RSE: {rse_value:.4f}")
            print(f"PSNR: {psnr_value:.4f}")
            print(f"SSIM: {ssim_value:.4f}")
            

# Example usage
input_folder = "/mnt/storage2/PanNuke/fold1/Thyroid/images"  # Path to folder with input images
output_folder = "/mnt/storage2/PanNuke/folder1/Ruifork_folder/ru_Testis"  # Path to folder for saving normalized images
reference_image_url = "https://data.kitware.com/api/v1/file/57718cc28d777f1ecd8a883c/download"  # URL for reference image

normalize_stains(input_folder, output_folder, reference_image_url)  # Execute the stain normalization process
# Out:
# Metrics for img_Testis_1_01411.png:
# PCC: 0.9878
# AMCE-alpha (Eα): 31.3334
# AMCE-beta (Eβ): 44.7301
# RSE: 0.0223
# PSNR: 19.8742
# SSIM: 0.9668
# --------------------------------------------------
# Metrics for img_Testis_1_01412.png:
# PCC: 0.9820
# AMCE-alpha (Eα): 40.6950
# AMCE-beta (Eβ): 37.7968
# RSE: 0.0290
# PSNR: 19.2900
# SSIM: 0.9705
# --------------------------------------------------
# Metrics for img_Testis_1_01413.png:
# PCC: 0.9840
# AMCE-alpha (Eα): 26.0973
# AMCE-beta (Eβ): 47.4595
# RSE: 0.0231
# PSNR: 20.1668
# SSIM: 0.9809
# --------------------------------------------------
# Metrics for img_Testis_1_01414.png:
# PCC: 0.9519
# AMCE-alpha (Eα): 31.6590
# AMCE-beta (Eβ): 44.5382
# RSE: 0.0372
# PSNR: 17.8234
# SSIM: 0.9765
# --------------------------------------------------
# Metrics for img_Testis_1_01415.png:
# PCC: 0.9671
# AMCE-alpha (Eα): 32.3548
# AMCE-beta (Eβ): 42.4486
# RSE: 0.0347
# PSNR: 18.4655
# SSIM: 0.9726
# --------------------------------------------------
# Metrics for img_Testis_1_01416.png:
# PCC: 0.9726
# AMCE-alpha (Eα): 20.0856
# AMCE-beta (Eβ): 50.7582
# RSE: 0.0285
# PSNR: 18.4536
# SSIM: 0.9600
# --------------------------------------------------
# Metrics for img_Testis_1_01417.png:
# PCC: 0.9748
# AMCE-alpha (Eα): 45.3583
# AMCE-beta (Eβ): 34.5035
# RSE: 0.0555
# PSNR: 15.8627
# SSIM: 0.9158
# --------------------------------------------------
# Metrics for img_Testis_1_01418.png:
# PCC: 0.9696
# AMCE-alpha (Eα): 24.9661
# AMCE-beta (Eβ): 46.8118
# RSE: 0.0308
# PSNR: 18.5990
# SSIM: 0.9650
# --------------------------------------------------
# Metrics for img_Testis_1_01419.png:
# PCC: 0.9542
# AMCE-alpha (Eα): 29.8555
# AMCE-beta (Eβ): 42.5363
# RSE: 0.0460
# PSNR: 17.0337
# SSIM: 0.9497
# --------------------------------------------------
# Metrics for img_Testis_1_01420.png:
# PCC: 0.9750
# AMCE-alpha (Eα): 32.3450
# AMCE-beta (Eβ): 43.3524
# RSE: 0.0423
# PSNR: 16.6952
# SSIM: 0.9349
# --------------------------------------------------
# Metrics for img_Testis_1_01421.png:
# PCC: 0.9497
# AMCE-alpha (Eα): 18.6859
# AMCE-beta (Eβ): 48.4854
# RSE: 0.0409
# PSNR: 17.2663
# SSIM: 0.9449
# --------------------------------------------------
# Metrics for img_Testis_1_01422.png:
# PCC: 0.9556
# AMCE-alpha (Eα): 28.4829
# AMCE-beta (Eβ): 43.6633
# RSE: 0.0415
# PSNR: 17.4552
# SSIM: 0.9472
# --------------------------------------------------
# Metrics for img_Testis_1_01423.png:
# PCC: 0.9637
# AMCE-alpha (Eα): 35.9290
# AMCE-beta (Eβ): 41.1259
# RSE: 0.0430
# PSNR: 17.0219
# SSIM: 0.9538
# --------------------------------------------------
# Metrics for img_Testis_1_01424.png:
# PCC: 0.9536
# AMCE-alpha (Eα): 21.1126
# AMCE-beta (Eβ): 48.1904
# RSE: 0.0375
# PSNR: 17.5995
# SSIM: 0.9449
# --------------------------------------------------
# Metrics for img_Testis_1_01425.png:
# PCC: 0.9614
# AMCE-alpha (Eα): 18.2617
# AMCE-beta (Eβ): 50.3011
# RSE: 0.0424
# PSNR: 17.5519
# SSIM: 0.9867
# --------------------------------------------------
# Metrics for img_Testis_1_01426.png:
# PCC: 0.9926
# AMCE-alpha (Eα): 5.1506
# AMCE-beta (Eβ): 59.2042
# RSE: 0.0116
# PSNR: 21.6931
# SSIM: 0.9821
# --------------------------------------------------
# Metrics for img_Testis_1_01427.png:
# PCC: 0.9881
# AMCE-alpha (Eα): 25.9555
# AMCE-beta (Eβ): 45.9860
# RSE: 0.0251
# PSNR: 19.4863
# SSIM: 0.9705
# --------------------------------------------------
# Metrics for img_Testis_1_01428.png:
# PCC: 0.9730
# AMCE-alpha (Eα): 31.5590
# AMCE-beta (Eβ): 40.9687
# RSE: 0.0455
# PSNR: 17.7459
# SSIM: 0.9614
# --------------------------------------------------
# Metrics for img_Testis_1_01429.png:
# PCC: 0.9947
# AMCE-alpha (Eα): 27.5396
# AMCE-beta (Eβ): 80.5266
# RSE: 0.0039
# PSNR: 25.2899
# SSIM: 0.9804
# --------------------------------------------------
# Metrics for img_Testis_1_01430.png:
# PCC: 0.9833
# AMCE-alpha (Eα): 22.4879
# AMCE-beta (Eβ): 80.6156
# RSE: 0.0063
# PSNR: 22.7579
# SSIM: 0.9701
# --------------------------------------------------
# Metrics for img_Testis_1_01431.png:
# PCC: 0.9762
# AMCE-alpha (Eα): 16.1846
# AMCE-beta (Eβ): 52.7045
# RSE: 0.0264
# PSNR: 19.0737
# SSIM: 0.9866
# --------------------------------------------------
# Metrics for img_Testis_1_01432.png:
# PCC: 0.9608
# AMCE-alpha (Eα): 13.2328
# AMCE-beta (Eβ): 61.4289
# RSE: 0.0521
# PSNR: 13.6196
# SSIM: 0.8423
# --------------------------------------------------
# Metrics for img_Testis_1_01433.png:
# PCC: 0.9546
# AMCE-alpha (Eα): 15.2939
# AMCE-beta (Eβ): 61.1657
# RSE: 0.0524
# PSNR: 13.5588
# SSIM: 0.8828
# --------------------------------------------------
# Metrics for img_Testis_1_01434.png:
# PCC: 0.9899
# AMCE-alpha (Eα): 10.8883
# AMCE-beta (Eβ): 69.2184
# RSE: 0.0095
# PSNR: 22.0252
# SSIM: 0.9877
# --------------------------------------------------
# Metrics for img_Testis_1_01435.png:
# PCC: 0.9671
# AMCE-alpha (Eα): 20.6150
# AMCE-beta (Eβ): 48.7913
# RSE: 0.0325
# PSNR: 18.3847
# SSIM: 0.9831
# --------------------------------------------------
# Metrics for img_Testis_1_01436.png:
# PCC: 0.9789
# AMCE-alpha (Eα): 15.6576
# AMCE-beta (Eβ): 51.3511
# RSE: 0.0282
# PSNR: 18.8648
# SSIM: 0.9774
# --------------------------------------------------
# Metrics for img_Testis_1_01437.png:
# PCC: 0.9956
# AMCE-alpha (Eα): 4.2243
# AMCE-beta (Eβ): 65.7413
# RSE: 0.0084
# PSNR: 22.7407
# SSIM: 0.9817
# --------------------------------------------------
# Metrics for img_Testis_1_01438.png:
# PCC: 0.9816
# AMCE-alpha (Eα): 13.0831
# AMCE-beta (Eβ): 53.1397
# RSE: 0.0306
# PSNR: 18.4541
# SSIM: 0.9663
# --------------------------------------------------
# Metrics for img_Testis_1_01439.png:
# PCC: 0.9825
# AMCE-alpha (Eα): 17.8301
# AMCE-beta (Eβ): 50.2744
# RSE: 0.0320
# PSNR: 18.5952
# SSIM: 0.9686
# --------------------------------------------------
# Metrics for img_Testis_1_01440.png:
# PCC: 0.9815
# AMCE-alpha (Eα): 13.8863
# AMCE-beta (Eβ): 52.8001
# RSE: 0.0313
# PSNR: 18.4603
# SSIM: 0.9750
# --------------------------------------------------
# Metrics for img_Testis_1_01441.png:
# PCC: 0.9793
# AMCE-alpha (Eα): 23.7191
# AMCE-beta (Eβ): 47.1645
# RSE: 0.0326
# PSNR: 18.6873
# SSIM: 0.9769
# --------------------------------------------------
# Metrics for img_Testis_1_01442.png:
# PCC: 0.9820
# AMCE-alpha (Eα): 29.0088
# AMCE-beta (Eβ): 43.4915
# RSE: 0.0466
# PSNR: 17.7210
# SSIM: 0.9613
# --------------------------------------------------
# Metrics for img_Testis_1_01443.png:
# PCC: 0.9572
# AMCE-alpha (Eα): 8.1071
# AMCE-beta (Eβ): 55.2719
# RSE: 0.0323
# PSNR: 17.8091
# SSIM: 0.9620
# --------------------------------------------------
# Metrics for img_Testis_1_01444.png:
# PCC: 0.9786
# AMCE-alpha (Eα): 33.7978
# AMCE-beta (Eβ): 40.7711
# RSE: 0.0404
# PSNR: 18.4539
# SSIM: 0.9761
# --------------------------------------------------
# Metrics for img_Testis_1_01445.png:
# PCC: 0.9717
# AMCE-alpha (Eα): 34.8499
# AMCE-beta (Eβ): 42.1560
# RSE: 0.0313
# PSNR: 19.2859
# SSIM: 0.9895
# --------------------------------------------------
# Metrics for img_Testis_1_02512.png:
# PCC: 0.9668
# AMCE-alpha (Eα): 56.1111
# AMCE-beta (Eβ): 25.2248
# RSE: 0.1091
# PSNR: 14.7039
# SSIM: 0.9815
# --------------------------------------------------
# Metrics for img_Testis_1_02513.png:
# PCC: 0.9655
# AMCE-alpha (Eα): 34.8174
# AMCE-beta (Eβ): 44.3686
# RSE: 0.0344
# PSNR: 17.9808
# SSIM: 0.9689
# --------------------------------------------------
# Metrics for img_Testis_1_02514.png:
# PCC: 0.9643
# AMCE-alpha (Eα): 46.5808
# AMCE-beta (Eβ): 34.5085
# RSE: 0.0599
# PSNR: 16.3863
# SSIM: 0.9731
# --------------------------------------------------
# Metrics for img_Testis_1_02515.png:
# PCC: 0.9708
# AMCE-alpha (Eα): 47.5404
# AMCE-beta (Eβ): 32.7517
# RSE: 0.0670
# PSNR: 16.0610
# SSIM: 0.9796
# --------------------------------------------------
# Metrics for img_Testis_1_02516.png:
# PCC: 0.9643
# AMCE-alpha (Eα): 37.8375
# AMCE-beta (Eβ): 43.2699
# RSE: 0.0329
# PSNR: 18.1982
# SSIM: 0.9698
# --------------------------------------------------
# Metrics for img_Testis_1_02517.png:
# PCC: 0.9327
# AMCE-alpha (Eα): 32.7078
# AMCE-beta (Eβ): 47.3966
# RSE: 0.0282
# PSNR: 18.3981
# SSIM: 0.7204
# --------------------------------------------------
# Metrics for img_Testis_1_02518.png:
# PCC: 0.9751
# AMCE-alpha (Eα): 23.3996
# AMCE-beta (Eβ): 55.9959
# RSE: 0.0202
# PSNR: 19.0952
# SSIM: 0.8682
# --------------------------------------------------
# Metrics for img_Testis_1_02519.png:
# PCC: 0.9624
# AMCE-alpha (Eα): 47.8648
# AMCE-beta (Eβ): 37.0308
# RSE: 0.0356
# PSNR: 17.7323
# SSIM: 0.7978
# --------------------------------------------------
# Metrics for img_Testis_1_02520.png:
# PCC: 0.9442
# AMCE-alpha (Eα): 20.9549
# AMCE-beta (Eβ): 56.0606
# RSE: 0.0211
# PSNR: 19.1247
# SSIM: 0.7204
# --------------------------------------------------
# Metrics for img_Testis_1_02521.png:
# PCC: 0.9806
# AMCE-alpha (Eα): 3.3325
# AMCE-beta (Eβ): 60.4024
# RSE: 0.0146
# PSNR: 21.1034
# SSIM: 0.9196
# --------------------------------------------------
# Metrics for img_Testis_1_02522.png:
# PCC: 0.9819
# AMCE-alpha (Eα): 47.5248
# AMCE-beta (Eβ): 33.6967
# RSE: 0.0492
# PSNR: 16.1627
# SSIM: 0.9068
# --------------------------------------------------
# Metrics for img_Testis_1_02523.png:
# PCC: 0.9829
# AMCE-alpha (Eα): 45.0534
# AMCE-beta (Eβ): 35.8988
# RSE: 0.0360
# PSNR: 17.8271
# SSIM: 0.9446
# --------------------------------------------------
# Metrics for img_Testis_1_02524.png:
# PCC: 0.9814
# AMCE-alpha (Eα): 43.2976
# AMCE-beta (Eβ): 35.8262
# RSE: 0.0454
# PSNR: 16.4813
# SSIM: 0.9130
# --------------------------------------------------
# Metrics for img_Testis_1_02525.png:
# PCC: 0.9839
# AMCE-alpha (Eα): 46.9376
# AMCE-beta (Eβ): 32.9108
# RSE: 0.0662
# PSNR: 17.5721
# SSIM: 0.9510
# --------------------------------------------------
# Metrics for img_Testis_1_02526.png:
# PCC: 0.9799
# AMCE-alpha (Eα): 47.2946
# AMCE-beta (Eβ): 32.5160
# RSE: 0.0688
# PSNR: 17.5301
# SSIM: 0.9619
# --------------------------------------------------
# Metrics for img_Testis_1_02527.png:
# PCC: 0.9813
# AMCE-alpha (Eα): 27.2716
# AMCE-beta (Eβ): 43.8122
# RSE: 0.0275
# PSNR: 19.9266
# SSIM: 0.9698
# --------------------------------------------------
# Metrics for img_Testis_1_02528.png:
# PCC: 0.9846
# AMCE-alpha (Eα): 49.1904
# AMCE-beta (Eβ): 30.8153
# RSE: 0.0558
# PSNR: 18.4027
# SSIM: 0.9576
# --------------------------------------------------
# Metrics for img_Testis_1_02529.png:
# PCC: 0.9863
# AMCE-alpha (Eα): 42.1886
# AMCE-beta (Eβ): 35.2527
# RSE: 0.0292
# PSNR: 20.2593
# SSIM: 0.9752
# --------------------------------------------------
# Metrics for img_Testis_1_02530.png:
# PCC: 0.9865
# AMCE-alpha (Eα): 45.1840
# AMCE-beta (Eβ): 33.5957
# RSE: 0.0327
# PSNR: 20.0338
# SSIM: 0.9739
# --------------------------------------------------
# Metrics for img_Testis_1_02531.png:
# PCC: 0.9749
# AMCE-alpha (Eα): 63.6163
# AMCE-beta (Eβ): 24.7510
# RSE: 0.0415
# PSNR: 18.5559
# SSIM: 0.9420
# --------------------------------------------------
# Metrics for img_Testis_1_02532.png:
# PCC: 0.9752
# AMCE-alpha (Eα): 57.8277
# AMCE-beta (Eβ): 27.8249
# RSE: 0.0372
# PSNR: 19.1301
# SSIM: 0.9488
# --------------------------------------------------
# Metrics for img_Testis_1_02533.png:
# PCC: 0.9784
# AMCE-alpha (Eα): 58.0681
# AMCE-beta (Eβ): 28.2033
# RSE: 0.0371
# PSNR: 18.9392
# SSIM: 0.9576
# --------------------------------------------------
# Metrics for img_Testis_1_02534.png:
# PCC: 0.9792
# AMCE-alpha (Eα): 58.7741
# AMCE-beta (Eβ): 26.6432
# RSE: 0.0432
# PSNR: 18.4042
# SSIM: 0.9530
# --------------------------------------------------
# Metrics for img_Testis_1_02535.png:
# PCC: 0.9833
# AMCE-alpha (Eα): 57.7996
# AMCE-beta (Eβ): 27.6157
# RSE: 0.0344
# PSNR: 19.1588
# SSIM: 0.9483
# --------------------------------------------------
# Metrics for img_Testis_1_02536.png:
# PCC: 0.9777
# AMCE-alpha (Eα): 61.0494
# AMCE-beta (Eβ): 27.3807
# RSE: 0.0367
# PSNR: 19.0958
# SSIM: 0.9667
# --------------------------------------------------
